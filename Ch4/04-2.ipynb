# %%
import sys
import os
sys.path.append("../")
from datapath import base_path, data_path
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fig = plt.figure()
axes1 = fig.add_subplot(1, 1, 1)

# %%
axes1.hist(tips["total_bill"], bins=10)
axes1.set_title("Histrogram of Total Bill")
axes1.set_xlabel("Frequency")
axes1.set_ylabel("Total Bill")
fig

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1, 1, 1)
axes1.scatter(tips["total_bill"], tips["tip"])
axes1.set_title("Scatterplot of Total Bill vs Tip")
axes1.set_xlabel("Total Bill")
axes1.set_ylabel("Tip")
# Out:
# Text(0, 0.5, 'Tip')

# %%
boxplot = plt.figure()
axes1 = boxplot.add_subplot(1, 1, 1)
axes1 = axes1.boxplot([
                        tips[tips["sex"] == "Female"]["tip"],
                        tips[tips["sex"] == "Male"]["tip"]
                       ],
                      labels=["Female", "Male"]
                      )
axes1.set_xlabel("Sex")
axes1.set_ylabel("Tip")
axes1.set_title("Boxplot of Tips by Sex")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 9
#       2 axes1 = boxplot.add_subplot(1, 1, 1)
#       3 axes1 = axes1.boxplot([
#       4                         tips[tips["sex"] == "Female"]["tip"],
#       5                         tips[tips["sex"] == "Male"]["tip"]
#       6                        ],
#       7                       labels=["Female", "Male"]
#       8                       )
# ----> 9 axes1.set_xlabel("Sex")
#      10 axes1.set_ylabel("Tip")
#      11 axes1.set_title("Boxplot of Tips by Sex")
#
# AttributeError: 'dict' object has no attribute 'set_xlabel'

# %%
recode_sex = lambda x:1 if (x=="Female") else 0
tips["sex_color"] = tips["sex"].apply(recode_sex)
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size sex_color
# 0       16.99  1.01  Female     No  Sun  Dinner     2         1
# 1       10.34  1.66    Male     No  Sun  Dinner     3         0
# 2       21.01  3.50    Male     No  Sun  Dinner     3         0
# 3       23.68  3.31    Male     No  Sun  Dinner     2         0
# 4       24.59  3.61  Female     No  Sun  Dinner     4         1

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1, 1, 1)
axes1.scatter(
    x=tips["total_bill"],
    y=tips["tip"],
    s=tips["size"] * 10, #table 당 인원수를 점의 크기로 치환하여 표현
    c=tips["sex_color"], # "sex_color 항목에 따라 점의 색을 다르게 표현"
    alpha=0.5
)
axes1.set_title("Total Bill vs Tip Colored by Sex and Sized by Size")
axes1.set_xlabel("Total Bill")
axes1.set_ylabel("Tip")
# Out:
# Text(0, 0.5, 'Tip')
