# %%
import sys
import os
sys.path.append("../")
from datapath import base_path, data_path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset("tips")
fig = sns.displot(data=tips, x='total_bill', kde=True, rug=True)

fig.set_axis_labels(x_var='Total Bill', y_var='Count')
fig.figure.suptitle('Distribution of Total Bill')

plt.show()

# %%
ax = plt.subplots()
# density function제외 kde=False
ax = sns.distplot(tips["total_bill"], kde=False)
ax.set_title("Total Bill Histogram")
ax.set_xlabel("Total_Bill")
ax.set_ylabel("Frequency")
# Out:
# C:\Users\Suseong Kim\AppData\Local\Temp\ipykernel_11416\956036775.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips["total_bill"], kde=False)
# Text(0, 0.5, 'Frequency')

# %%
ax = plt.subplots()
# histogram graph 끄기 -> hist = False
ax = sns.distplot(tips["total_bill"], hist=False)
ax.set_title("Total Bill Density")
ax.set_xlabel("Total Bill")
ax.set_ylabel("Unit Probability")
# Out:
# C:\Users\Suseong Kim\AppData\Local\Temp\ipykernel_11416\3339382496.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips["total_bill"], hist=False)
# Text(0, 0.5, 'Unit Probability')

# %%
ax = plt.subplots()
ax = sns.distplot(tips["total_bill"], rug=True)
ax.set_title("Total Bill Histoream with Density and Rug Plot")
ax.set_xlabel("Total Bill")
# Out:
# C:\Users\Suseong Kim\AppData\Local\Temp\ipykernel_11416\3044836948.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips["total_bill"], rug=True)
# Text(0.5, 0, 'Total Bill')

# %%
count, ax = plt.subplots()
print(type(count))
print(type(ax))
sns.countplot(data=tips, x="day", palette="viridis", ax=ax)
ax.set_title("Count_of_days")
ax.set_xlabel("Day of the Week")
ax.set_ylabel("Frequency")
plt.show()
# Out:
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.axes._axes.Axes'>
# C:\Users\Suseong Kim\AppData\Local\Temp\ipykernel_11416\4265230471.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=tips, x="day", palette="viridis", ax=ax)

# %%
# SUBPLOT 반환값 저장
scatter, ax = plt.subplots()
#SNS 라이브러리에서 함수 호출
sns.scatterplot(data=tips, x="total_bill", y="tip", ax=ax)
ax.set_title("Scatter Plot of Total bill and Tip")
ax.set_xlabel("Total Bill")
ax.set_ylabel("Tip")

plt.show()

# %%
reg, ax = plt.subplots()
ax = sns.regplot(x="total_bill", y="tip", data=tips, ax=ax)
ax.set_title("Scatterplot of Total Bill and Tip")
ax.set_xlabel("Total Bill")
ax.set_ylabel("Tip")
# Out:
# Text(0, 0.5, 'Tip')

# %%
ax = plt.subplots()
ax = sns.regplot(x="total_bill", y="tip", data=tips, fit_reg=False)
ax.set_title("Scatterplot of Total Bill and Tip")
ax.set_xlabel("Total Bill")
ax.set_ylabel("Tip")
# Out:
# Text(0, 0.5, 'Tip')

# %%
joint = sns.jointplot(data=tips, x="total_bill", y="tip")
joint.set_axis_labels(xlabel="Total Bill", ylabel="Tip")
joint.figure.suptitle("Joint Plot of Total Bill and Tip", y=1.03)
plt.show()

# %%
hexbin = sns.jointplot(data=tips, x="total_bill", y="tip", kind="hex")

hexbin.set_axis_labels(xlabel="Total Bill", ylabel="Tip")
hexbin.figure.suptitle("Hexbin Joint Plot of Total Bill and Tip")
plt.show()

# %%
plt.clf()
kde, ax = plt.subplots()
tips = sns.load_dataset("tips")
sns.kdeplot(data=tips, x="total_bill", y="tip", fill=True)

ax.set_title("Kernel Density Plot of Total Bill and Tip")
ax.set_xlabel("Total Bill")
ax.set_ylabel("Tip")
plt.show()

# %%
import numpy as np

bar, ax = plt.subplots()

sns.barplot(data=tips, x="time", y="total_bill", \
    estimator=np.mean, ax=ax)
ax.set_title("Bar Plot of Average Total bill fot Tile of Day")
ax.set_xlabel("time of Day")
ax.set_ylabel("Average Totla Bill")

plt.show()

# %%
box, ax = plt.subplots()
sns.boxplot(data=tips, x="time", y="total_bill", ax=ax)
ax.set_title("Box Plot of Total Bill for Time of Day")
ax.set_xlabel("Time of Day")
ax.set_ylabel("Total Bill")

plt.show()

# %%
ax = plt.subplots()
ax = sns.violinplot(x="time", y="total_bill", data=tips)
ax.set_title("Violin plot of total bill by time of day")
ax.set_xlabel("Time of day")
ax.set_ylabel("Total Bill")
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
fig = sns.pairplot(tips)

# %%
pair_grid = sns.PairGrid(tips, diag_sharey=False)
pair_grid = pair_grid.map_upper(sns.regplot)
pair_grid = pair_grid.map_lower(sns.kdeplot)
pair_grid = pair_grid.map_diag(sns.histplot)

# %%
violin, ax = plt.subplots()
sns.violinplot(data=tips,
               x="time",
               y="total_bill",
               hue="smoker",
               split=True,
               palette="viridis",
               ax=ax)
plt.show()

# %%
scatter = sns.lmplot(
    data = tips,
    x= "total_bill",
    y = "tip",
    hue = "smoker",
    fit_reg=False,
    palette="viridis"
)
plt.show()

# %%
fig = sns.pairplot(tips, hue="sex")

# %%
fig, ax = plt.subplots()
sns.scatterplot(data=tips, 
                x="total_bill",
                y="tip",
                hue="time",
                size="size",
                palette="viridis",
                ax=ax)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
anscombe = sns.load_dataset("anscombe")

# %%
anscombe_plot = sns.relplot(
    data=anscombe,
    x="x",
    y="y",
    kind="scatter",
    col="dataset",
    col_wrap=2,
    height=2,
    # col_wrap, height => 전체플롯의 높이, 너비를 결정하는 인자.
    aspect=1.6
    # aspect = 가로길이.
)
